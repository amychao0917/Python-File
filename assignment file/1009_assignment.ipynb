# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
labels='board expenses','novels','movies','clothing'
size=[3000,500,420,599]
separated=[.1,0,0,0]
plt.pie(size,labels=labels,autopct='%1.1f%%',explode=separated)
plt.axis('equal')
plt.show()
