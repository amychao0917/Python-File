# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
H = np.linspace(0,2*np.pi,1024)

# %%
plt.axes(polar=True)
plt.plot(H,1-np.sin(H),color='y')
plt.show()
