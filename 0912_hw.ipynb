# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
x=np. linspace(-1,120,1000)

# %%
y=np.cos(x)*x

# %%
y[y>30]=np.inf
y[y<-60]=-np.inf

# %%
plt.plot(x,y)

# %% [markdown]
# ![me](220px-Abraham_Maslow.jpg)
